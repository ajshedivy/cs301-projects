# %%
def Q1():
    print("What is the type of the following? 1.0 + 2.0")
    print("a) int")
    print("b) float")
    print("c) str")
    print("d) bool")
    print("e) NoneType")
   
        

    
def Q2():
    print("What is the type of the following?")
    print("1 * 2")
        

    
def Q3():
    print("What does this expression evaluate to?")
    print("True != (3 < 2)")

        


def call_q():
    w = input("how many tries: ")
    w =int(w)
    print("What is the type of the following? 1.0 + 2.0")
    print("a) int")
    print("b) float")
    print("c) str")
    print("d) bool")
    print("e) NoneType")
    while w > 0:
        response= answer1 = input("your answer ")
        if response.strip().lower() == "float":
            print("correct answer")
            print("What is the type of the following?")
            print("1 * 2")   
            while w > 0 :
                response = answer2 = input("your answer ")
                if response.strip().lower() == "int":
                    print("Correct answer")
                    print("What does this expression evaluate to?")
                    print("True != (3 < 2)")
                    while w > 0:
                        response = answer3 = input("your answer ")
                        if response.strip().lower() == "true":
                            print("correct answer")
                        else:
                            w = w-1 
                            print(w)
                            Q3()
                    
                else:
                    w = w-1 
                    print(w)
                    Q2()
        
            
        else:
            w = w-1
            print(w)
            Q1()
    
    print("What is the type of the following?")
    print("1 * 2")   
    while w > 0 :
        response = answer2 = input("your answer ")
        if response.strip().lower() == "int":
            print("Correct answer")
            continue
        else:
            w = w-1 
            print(w)
            Q2()

def ask_questions():

# %%
call_q()
# Out:
# how many tries: 6
# What is the type of the following? 1.0 + 2.0
# a) int
# b) float
# c) str
# d) bool
# e) NoneType
# your answer f
# 5
# What is the type of the following? 1.0 + 2.0
# a) int
# b) float
# c) str
# d) bool
# e) NoneType
# your answer g
# 4
# What is the type of the following? 1.0 + 2.0
# a) int
# b) float
# c) str
# d) bool
# e) NoneType
# your answer flaot
# 3
# What is the type of the following? 1.0 + 2.0
# a) int
# b) float
# c) str
# d) bool
# e) NoneType
# your answer float
# correct answer
# What is the type of the following?
# 1 * 2
# your answer int
# Correct answer
# What does this expression evaluate to?
# True != (3 < 2)
# your answer flase
# 2
# What does this expression evaluate to?
# True != (3 < 2)
# your answer true
# correct answer

# %%
print(answer1)
